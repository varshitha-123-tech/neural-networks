# %% [markdown]
# <a href="https://colab.research.google.com/github/varshitha-123-tech/neural-networks/blob/main/Wekk4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras tensorflow

# %%
import pandas
from keras.models import Sequential
from keras.layers import Dense, Activation


# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

from google.colab import files
uploaded = files.upload()

dataset = pd.read_csv("diabetes.csv", header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
#      <input type="file" id="files-19825d31-89e1-40f0-be3e-95d3e879d0ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19825d31-89e1-40f0-be3e-95d3e879d0ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# a. Add more Dense layers to the existing code and check how the accuracy changes.

# %%
# Step 1: Import Required Libraries
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split



# Step2: Update the path based on where your dataset is stored
from google.colab import files
uploaded = files.upload()
dataset = pd.read_csv("diabetes.csv", header=None).values


# Step 3: Split the Data into Training and Testing Sets
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:, 0:8], dataset[:, 8], test_size=0.25, random_state=87)
np.random.seed(155)

# Step 4: Define the Neural Network Model with Additional Layers
model = Sequential()
model.add(Dense(20, input_dim=8, activation='relu'))  # First hidden layer
model.add(Dense(16, activation='relu'))  # Second hidden layer (New)
model.add(Dense(12, activation='relu'))  # Third hidden layer (New)
model.add(Dense(8, activation='relu'))  # Fourth hidden layer (New)
model.add(Dense(1, activation='sigmoid'))  # Output layer

# Step 5: Compile the Model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Step 6: Train the Model
history = model.fit(X_train, Y_train, epochs=100, verbose=1)

# Step 7: Evaluate the Model
print(model.summary())
loss, accuracy = model.evaluate(X_test, Y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
#      <input type="file" id="files-d62430d0-162d-4a25-bd9a-ca1857f287bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d62430d0-162d-4a25-bd9a-ca1857f287bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 2. Change the data source to Breast Cancer dataset * available in the source code folder and make required
# changes. Report accuracy of the model.

# %%
# Step 1: Import Required Libraries
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from google.colab import files

# Step 2: Manually Upload the Breast Cancer Dataset
uploaded = files.upload()

# Get the filename of the uploaded file
file_name = list(uploaded.keys())[0]

# Step 3: Load the Dataset
dataset = pd.read_csv(file_name)  # Read the uploaded file

# Step 4: Preprocess the Data
dataset = dataset.drop(columns=['id'])  # Remove ID column (not useful for training)

# Convert 'diagnosis' column (M=1, B=0)
label_encoder = LabelEncoder()
dataset['diagnosis'] = label_encoder.fit_transform(dataset['diagnosis'])

# Split features (X) and target (Y)
X = dataset.drop(columns=['diagnosis']).values  # All feature columns
Y = dataset['diagnosis'].values  # Target labels (0 or 1)

# Split into Training and Testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=87)
np.random.seed(155)

# Step 5: Define the Neural Network Model
model = Sequential()
model.add(Dense(30, input_dim=X.shape[1], activation='relu'))  # First hidden layer
model.add(Dense(16, activation='relu'))  # Second hidden layer
model.add(Dense(8, activation='relu'))  # Third hidden layer
model.add(Dense(1, activation='sigmoid'))  # Output layer (Binary classification)

# Step 6: Compile the Model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Step 7: Train the Model
history = model.fit(X_train, Y_train, epochs=100, verbose=1)

# Step 8: Evaluate the Model
print(model.summary())
loss, accuracy = model.evaluate(X_test, Y_test)
print(f"Test Accuracy on Breast Cancer Dataset: {accuracy * 100:.2f}%")
# Out:
#      <input type="file" id="files-0a513c47-499b-4b11-86fa-d60ed1678494" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a513c47-499b-4b11-86fa-d60ed1678494">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 3. Normalize the data before feeding the data to the model and check how the normalization change your
# accuracy (code given below).
#
# from sklearn.preprocessing import StandardScaler
#
# sc = StandardScaler()

# %%
# Step 1: Import Required Libraries
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from google.colab import files

# Step 2: Manually Upload the Breast Cancer Dataset
uploaded = files.upload()
# Get the filename of the uploaded file
file_name = list(uploaded.keys())[0]

# Step 3: Load the Dataset
dataset = pd.read_csv(file_name)  # Read the uploaded file

# Step 4: Preprocess the Data
dataset = dataset.drop(columns=['id'])  # Remove ID column (not useful for training)

# Convert 'diagnosis' column (M=1, B=0)
label_encoder = LabelEncoder()
dataset['diagnosis'] = label_encoder.fit_transform(dataset['diagnosis'])

# Split features (X) and target (Y)
X = dataset.drop(columns=['diagnosis']).values  # All feature columns
Y = dataset['diagnosis'].values  # Target labels (0 or 1)

# 🔹 Step 5: Normalize the Data using StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)  # Apply normalization

# Split into Training and Testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=87)
np.random.seed(155)

# Step 6: Define the Neural Network Model
model = Sequential()
model.add(Dense(30, input_dim=X.shape[1], activation='relu'))  # First hidden layer
model.add(Dense(16, activation='relu'))  # Second hidden layer
model.add(Dense(8, activation='relu'))  # Third hidden layer
model.add(Dense(1, activation='sigmoid'))  # Output layer (Binary classification)

# Step 7: Compile the Model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Step 8: Train the Model
history = model.fit(X_train, Y_train, epochs=100, verbose=1)

# Step 9: Evaluate the Model
print(model.summary())
loss, accuracy = model.evaluate(X_test, Y_test)
print(f"🔹 Test Accuracy with Normalization: {accuracy * 100:.2f}%")
# Out:
#      <input type="file" id="files-11569382-0618-4f50-893b-71570ab6e907" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-11569382-0618-4f50-893b-71570ab6e907">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Use Image Classification on the hand written digits data set (mnist)

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (28, 28)
# 784
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.8402 - loss: 0.5242 - val_accuracy: 0.9543 - val_loss: 0.1484
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9659 - loss: 0.1082 - val_accuracy: 0.9673 - val_loss: 0.1017
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.9803 - loss: 0.0639 - val_accuracy: 0.9591 - val_loss: 0.1301
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9852 - loss: 0.0460 - val_accuracy: 0.9702 - val_loss: 0.0943
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.9910 - loss: 0.0291 - val_accuracy: 0.9792 - val_loss: 0.0707
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.9939 - loss: 0.0211 - val_accuracy: 0.9456 - val_loss: 0.1829
# Epoch 7/10
# ...

# %% [markdown]
# 1. Plot the loss and accuracy for both training data and validation data using the history object in the source
# code.

# %%
import matplotlib.pyplot as plt

# Extract loss and accuracy from history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Plot Loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training vs Validation Loss')

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy', color='blue')
plt.plot(val_acc, label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training vs Validation Accuracy')

plt.show()

# %% [markdown]
# 2. Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model
# on that single image.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Select an image from the test dataset (change index to test different images)
index = 5  # Try different numbers to test other images
test_image = test_images[index]  # Original 28x28 image

# Plot the selected image
plt.imshow(test_image, cmap='gray')
plt.title(f"True Label: {test_labels[index]}")
plt.axis('off')  # Hide axes
plt.show()

# Preprocess the image for prediction
test_image_processed = test_image.reshape(1, 784)  # Flatten to (1, 784) shape
test_image_processed = test_image_processed.astype('float') / 255.0  # Normalize (since model was trained with scaling)

# Model prediction
prediction = model.predict(test_image_processed)
predicted_label = np.argmax(prediction)

# Print the prediction result
print(f"🔹 Model Prediction: {predicted_label}")
print(f"🔹 True Label: {test_labels[index]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 🔹 Model Prediction: 1
# 🔹 True Label: 1

# %% [markdown]
# 3. We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the
# activation to tanh or sigmoid and see what happens.

# %%
# Import required libraries
from keras.models import Sequential
from keras.layers import Dense

# Create a modified model with different activation functions & more layers
model_tanh = Sequential()
model_tanh.add(Dense(512, activation='tanh', input_shape=(784,)))  # First hidden layer
model_tanh.add(Dense(512, activation='tanh'))  # Second hidden layer
model_tanh.add(Dense(256, activation='tanh'))  # New third hidden layer
model_tanh.add(Dense(10, activation='softmax'))  # Output layer

# Compile the model
model_tanh.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history_tanh = model_tanh.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                              validation_data=(test_data, test_labels_one_hot))

# Evaluate the modified model
loss_tanh, accuracy_tanh = model_tanh.evaluate(test_data, test_labels_one_hot)
print(f"🔹 Test Accuracy with Tanh Activation: {accuracy_tanh * 100:.2f}%")
# Out:
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.8160 - loss: 0.5838 - val_accuracy: 0.9238 - val_loss: 0.2534
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - accuracy: 0.9512 - loss: 0.1642 - val_accuracy: 0.9364 - val_loss: 0.1842
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.9688 - loss: 0.1025 - val_accuracy: 0.9712 - val_loss: 0.0940
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - accuracy: 0.9782 - loss: 0.0722 - val_accuracy: 0.9506 - val_loss: 0.1486
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9840 - loss: 0.0517 - val_accuracy: 0.9745 - val_loss: 0.0792
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9896 - loss: 0.0354 - val_accuracy: 0.9743 - val_loss: 0.0839
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 0.9919 - loss: 0.0267 - val_accuracy: 0.9667 - val_loss: 0.1110
# Epoch 8/10
# ...

# %% [markdown]
# 4. Run the same code without scaling the images and check the performance?

# %%
# Load the dataset again (without scaling)
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Flatten images to 1D arrays (28x28 → 784)
train_data_no_scaling = train_images.reshape(train_images.shape[0], 784)
test_data_no_scaling = test_images.reshape(test_images.shape[0], 784)

# Convert labels to one-hot encoding
train_labels_one_hot_no_scaling = to_categorical(train_labels)
test_labels_one_hot_no_scaling = to_categorical(test_labels)

# Create the same model architecture
model_no_scaling = Sequential()
model_no_scaling.add(Dense(512, activation='relu', input_shape=(784,)))  # First hidden layer
model_no_scaling.add(Dense(512, activation='relu'))  # Second hidden layer
model_no_scaling.add(Dense(10, activation='softmax'))  # Output layer

# Compile the model
model_no_scaling.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model without scaling the images
history_no_scaling = model_no_scaling.fit(train_data_no_scaling, train_labels_one_hot_no_scaling, batch_size=256, epochs=10, verbose=1,
                                          validation_data=(test_data_no_scaling, test_labels_one_hot_no_scaling))

# Evaluate the model
loss_no_scaling, accuracy_no_scaling = model_no_scaling.evaluate(test_data_no_scaling, test_labels_one_hot_no_scaling)
print(f"🔹 Test Accuracy Without Scaling: {accuracy_no_scaling * 100:.2f}%")
# Out:
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.7862 - loss: 22.1047 - val_accuracy: 0.9227 - val_loss: 0.8007
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9442 - loss: 0.4800 - val_accuracy: 0.9219 - val_loss: 0.4707
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.9586 - loss: 0.2395 - val_accuracy: 0.9562 - val_loss: 0.2836
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.9677 - loss: 0.1677 - val_accuracy: 0.9622 - val_loss: 0.2124
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.9750 - loss: 0.1323 - val_accuracy: 0.9577 - val_loss: 0.2638
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.9771 - loss: 0.1176 - val_accuracy: 0.9605 - val_loss: 0.3594
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9785 - loss: 0.1331 - val_accuracy: 0.9475 - val_loss: 0.5609
# Epoch 8/10
# ...

# %% [markdown]
# video link : https://drive.google.com/file/d/17E6a4r99CpirSAMCOExu3hnrMexPdHh_/view?usp=drive_link
